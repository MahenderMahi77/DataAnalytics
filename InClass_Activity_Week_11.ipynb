# %%
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
cars = sns.load_dataset('mpg')

# %%
pd.concat([tips,cars])
# Out:
#      total_bill   tip     sex smoker  day    time  size   mpg  cylinders  \
# 0         16.99  1.01  Female     No  Sun  Dinner   2.0   NaN        NaN
# 1         10.34  1.66    Male     No  Sun  Dinner   3.0   NaN        NaN
# 2         21.01  3.50    Male     No  Sun  Dinner   3.0   NaN        NaN
# 3         23.68  3.31    Male     No  Sun  Dinner   2.0   NaN        NaN
# 4         24.59  3.61  Female     No  Sun  Dinner   4.0   NaN        NaN
# ..          ...   ...     ...    ...  ...     ...   ...   ...        ...
# 393         NaN   NaN     NaN    NaN  NaN     NaN   NaN  27.0        4.0
# 394         NaN   NaN     NaN    NaN  NaN     NaN   NaN  44.0        4.0
# 395         NaN   NaN     NaN    NaN  NaN     NaN   NaN  32.0        4.0
# 396         NaN   NaN     NaN    NaN  NaN     NaN   NaN  28.0        4.0
# 397         NaN   NaN     NaN    NaN  NaN     NaN   NaN  31.0        4.0
#
#      displacement  horsepower  weight  acceleration  model_year  origin  \
# ...

# %%
df1 = pd.DataFrame({'employee': ['Bob', 'Jake', 'Lisa', 'Sue'],
                    'department': ['Accounting', 'Engineering', 'Engineering', 'HR'],
                   'region': ['Toronto', 'Montreal', 'Winnipeg', 'Calgary']
                   })
df2 = pd.DataFrame({'employee': ['Lisa', 'Bob', 'Jake', 'Sue'],
                    'hire_date': [2004, 2008, 2012, 2014],
                  'travel_required': ['yes', 'yes', 'no', 'yes']
                   })

# %%
display(df1,df2)
# Out:
#   employee   department    region
# 0      Bob   Accounting   Toronto
# 1     Jake  Engineering  Montreal
# 2     Lisa  Engineering  Winnipeg
# 3      Sue           HR   Calgary
#   employee  hire_date travel_required
# 0     Lisa       2004             yes
# 1      Bob       2008             yes
# 2     Jake       2012              no
# 3      Sue       2014             yes

# %%
pd.merge(df1,df2)
# Out:
#   employee   department    region  hire_date travel_required
# 0      Bob   Accounting   Toronto       2008             yes
# 1     Jake  Engineering  Montreal       2012              no
# 2     Lisa  Engineering  Winnipeg       2004             yes
# 3      Sue           HR   Calgary       2014             yes

# %%
competitions = pd.read_csv(r'C:\Users\SHASHI\OneDrive\Analytics\Datasets\Football_Transfermarkt\competitions.csv')

# %%
clubs = pd.read_csv(r'C:\Users\SHASHI\OneDrive\Analytics\Datasets\Football_Transfermarkt\clubs.csv')

# %%
display(clubs,competitions)
# Out:
#      club_id             club_code                  name  \
# 0        105       sv-darmstadt-98       SV Darmstadt 98
# 1      11127     ural-ekaterinburg    Ural Yekaterinburg
# 2        114     besiktas-istanbul           Besiktas JK
# 3         12                as-rom               AS Roma
# 4        148     tottenham-hotspur     Tottenham Hotspur
# ..       ...                   ...                   ...
# 421    68608      cf-os-belenenses      CF Os Belenenses
# 422      724           fc-volendam           FC Volendam
# 423      800      atalanta-bergamo           Atalanta BC
# 424      979         moreirense-fc         Moreirense FC
# 425      984  west-bromwich-albion  West Bromwich Albion
#
#     domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                        L1                 NaN          29         26.1
# 1                       RU1                 NaN          25         27.6
# ...

# %%
club_games = pd.read_csv(r'C:\Users\SHASHI\OneDrive\Analytics\Datasets\Football_Transfermarkt\club_games.csv')

# %%
clubs.head()
# Out:
#    club_id          club_code                name domestic_competition_id  \
# 0      105    sv-darmstadt-98     SV Darmstadt 98                      L1
# 1    11127  ural-ekaterinburg  Ural Yekaterinburg                     RU1
# 2      114  besiktas-istanbul         Besiktas JK                     TR1
# 3       12             as-rom             AS Roma                     IT1
# 4      148  tottenham-hotspur   Tottenham Hotspur                     GB1
#
#    total_market_value  squad_size  average_age  foreigners_number  \
# 0                 NaN          29         26.1                 11
# 1                 NaN          25         27.6                 13
# 2                 NaN          32         26.7                 16
# 3                 NaN          26         26.7                 17
# 4                 NaN          29         25.6                 21
#
#    foreigners_percentage  national_team_players  \
# 0                   37.9                      1
# ...

# %%
club_games.head()
# Out:
#    game_id  club_id  own_goals  own_position      own_manager_name  \
# 0  2221751      431        1.0           NaN         Lutz Göttling
# 1  2221755       83        3.0           NaN      Ralph Hasenhüttl
# 2  2222597     3725        2.0           2.0  Stanislav Cherchesov
# 3  2222627     2696        0.0          11.0        Andrey Kobelev
# 4  2222658     2410        0.0           2.0        Leonid Slutski
#
#    opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# 0           60             2.0                NaN     Christian Streich
# 1         4795             0.0                NaN            Tomas Oral
# 2          232             1.0                5.0            Unai Emery
# 3         4128             2.0               10.0         Rustem Khuzin
# 4          121             2.0               13.0          Dan Petrescu
#
#   hosting  is_win
# 0    Home       0
# 1    Home       1
# 2    Home       1
# 3    Home       0
# 4    Home       0
